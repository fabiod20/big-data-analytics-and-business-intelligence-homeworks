# %% [markdown]
# # Homework 3 - MongoDB

# %%
import json
import os

# %%
dati_covid_path = './dataset/dpc-covid19-ita-regioni.json'
dati_vaccini_path = './dataset/somministrazioni-vaccini-latest.json'

dataset_dir = './dataset/'
dati_covid_path = os.path.join(dataset_dir, 'dpc-covid19-ita-regioni.json')
dati_vaccini_path = os.path.join(dataset_dir, 'somministrazioni-vaccini-latest.json')

dati_covid = []
with open(dati_covid_path, 'r') as j:
    dati_covid = json.load(j)

dati_vaccini = []
with open(dati_vaccini_path, 'r') as j:
    dati_vaccini = json.load(j)

# %%
dati_vaccini
# Out:
# {'data': [{'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 1,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 0,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 1},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 4,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 1,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 4,
#    'seconda_dose': 0,
#    'sesso_femminile': 3,
#    'sesso_maschile': 1},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 7,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 2,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 7,
#    'seconda_dose': 0,
#    'sesso_femminile': 6,
#    'sesso_maschile': 1},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 9,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 3,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 5,
#    'sesso_maschile': 4},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 13,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 4,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 14,
#    'seconda_dose': 0,
#    'sesso_femminile': 4,
#    'sesso_maschile': 10},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 5,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 1},
#   {'area': 'ABR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF1',
#    'codice_regione_ISTAT': 13,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 6,
#    'nome_area': 'Abruzzo',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 1},
#   {'area': 'BAS',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 9,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF5',
#    'codice_regione_ISTAT': 17,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 7,
#    'nome_area': 'Basilicata',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 5,
#    'sesso_maschile': 4},
#   {'area': 'BAS',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 1,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 27,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF5',
#    'codice_regione_ISTAT': 17,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 8,
#    'nome_area': 'Basilicata',
#    'prima_dose': 28,
#    'seconda_dose': 0,
#    'sesso_femminile': 18,
#    'sesso_maschile': 10},
#   {'area': 'BAS',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 1,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 29,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF5',
#    'codice_regione_ISTAT': 17,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 9,
#    'nome_area': 'Basilicata',
#    'prima_dose': 30,
#    'seconda_dose': 0,
#    'sesso_femminile': 23,
#    'sesso_maschile': 7},
#   {'area': 'BAS',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 26,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF5',
#    'codice_regione_ISTAT': 17,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 10,
#    'nome_area': 'Basilicata',
#    'prima_dose': 26,
#    'seconda_dose': 0,
#    'sesso_femminile': 15,
#    'sesso_maschile': 11},
#   {'area': 'BAS',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 13,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF5',
#    'codice_regione_ISTAT': 17,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 11,
#    'nome_area': 'Basilicata',
#    'prima_dose': 13,
#    'seconda_dose': 0,
#    'sesso_femminile': 4,
#    'sesso_maschile': 9},
#   {'area': 'CAL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 49,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF6',
#    'codice_regione_ISTAT': 18,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 12,
#    'nome_area': 'Calabria',
#    'prima_dose': 49,
#    'seconda_dose': 0,
#    'sesso_femminile': 34,
#    'sesso_maschile': 15},
#   {'area': 'CAL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 43,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF6',
#    'codice_regione_ISTAT': 18,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 13,
#    'nome_area': 'Calabria',
#    'prima_dose': 43,
#    'seconda_dose': 0,
#    'sesso_femminile': 20,
#    'sesso_maschile': 23},
#   {'area': 'CAL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 50,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF6',
#    'codice_regione_ISTAT': 18,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 14,
#    'nome_area': 'Calabria',
#    'prima_dose': 50,
#    'seconda_dose': 0,
#    'sesso_femminile': 27,
#    'sesso_maschile': 23},
#   {'area': 'CAL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 76,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF6',
#    'codice_regione_ISTAT': 18,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 15,
#    'nome_area': 'Calabria',
#    'prima_dose': 77,
#    'seconda_dose': 0,
#    'sesso_femminile': 28,
#    'sesso_maschile': 49},
#   {'area': 'CAL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 60,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF6',
#    'codice_regione_ISTAT': 18,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 16,
#    'nome_area': 'Calabria',
#    'prima_dose': 60,
#    'seconda_dose': 0,
#    'sesso_femminile': 16,
#    'sesso_maschile': 44},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 59,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 17,
#    'nome_area': 'Campania',
#    'prima_dose': 60,
#    'seconda_dose': 0,
#    'sesso_femminile': 33,
#    'sesso_maschile': 27},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 1,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 122,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 2,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 18,
#    'nome_area': 'Campania',
#    'prima_dose': 125,
#    'seconda_dose': 0,
#    'sesso_femminile': 64,
#    'sesso_maschile': 61},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 164,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 3,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 19,
#    'nome_area': 'Campania',
#    'prima_dose': 167,
#    'seconda_dose': 0,
#    'sesso_femminile': 87,
#    'sesso_maschile': 80},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 1,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 187,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 8,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 20,
#    'nome_area': 'Campania',
#    'prima_dose': 196,
#    'seconda_dose': 0,
#    'sesso_femminile': 77,
#    'sesso_maschile': 119},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 167,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 21,
#    'nome_area': 'Campania',
#    'prima_dose': 167,
#    'seconda_dose': 0,
#    'sesso_femminile': 37,
#    'sesso_maschile': 130},
#   {'area': 'CAM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 1,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 4,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF3',
#    'codice_regione_ISTAT': 15,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 22,
#    'nome_area': 'Campania',
#    'prima_dose': 5,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 5},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 27,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 111,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 23,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 139,
#    'seconda_dose': 0,
#    'sesso_femminile': 86,
#    'sesso_maschile': 53},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 12,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 129,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 24,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 141,
#    'seconda_dose': 0,
#    'sesso_femminile': 83,
#    'sesso_maschile': 58},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 25,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 200,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 25,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 227,
#    'seconda_dose': 0,
#    'sesso_femminile': 147,
#    'sesso_maschile': 80},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 25,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 259,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 3,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 26,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 287,
#    'seconda_dose': 0,
#    'sesso_femminile': 217,
#    'sesso_maschile': 70},
#   {'area': 'EMR',
#    'categoria_60_69': 24,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 123,
#    'categoria_ospiti_rsa': 3,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 27,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 150,
#    'seconda_dose': 0,
#    'sesso_femminile': 51,
#    'sesso_maschile': 99},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 1,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 3,
#    'categoria_ospiti_rsa': 8,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 28,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 13,
#    'seconda_dose': 0,
#    'sesso_femminile': 3,
#    'sesso_maschile': 10},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 8,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 29,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 8,
#    'seconda_dose': 0,
#    'sesso_femminile': 6,
#    'sesso_maschile': 2},
#   {'area': 'EMR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 5,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH5',
#    'codice_regione_ISTAT': 8,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '90+',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 30,
#    'nome_area': 'Emilia-Romagna',
#    'prima_dose': 5,
#    'seconda_dose': 0,
#    'sesso_femminile': 5,
#    'sesso_maschile': 0},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 4,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 31,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 5,
#    'seconda_dose': 0,
#    'sesso_femminile': 4,
#    'sesso_maschile': 1},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 16,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 32,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 16,
#    'seconda_dose': 0,
#    'sesso_femminile': 7,
#    'sesso_maschile': 9},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 50,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 33,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 50,
#    'seconda_dose': 0,
#    'sesso_femminile': 33,
#    'sesso_maschile': 17},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 100,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 2,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 34,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 102,
#    'seconda_dose': 0,
#    'sesso_femminile': 44,
#    'sesso_maschile': 58},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 84,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 35,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 84,
#    'seconda_dose': 0,
#    'sesso_femminile': 23,
#    'sesso_maschile': 61},
#   {'area': 'FVG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 5,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH4',
#    'codice_regione_ISTAT': 6,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 36,
#    'nome_area': 'Friuli-Venezia Giulia',
#    'prima_dose': 5,
#    'seconda_dose': 0,
#    'sesso_femminile': 2,
#    'sesso_maschile': 3},
#   {'area': 'LAZ',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 64,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI4',
#    'codice_regione_ISTAT': 12,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 37,
#    'nome_area': 'Lazio',
#    'prima_dose': 64,
#    'seconda_dose': 0,
#    'sesso_femminile': 32,
#    'sesso_maschile': 32},
#   {'area': 'LAZ',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 77,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI4',
#    'codice_regione_ISTAT': 12,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 38,
#    'nome_area': 'Lazio',
#    'prima_dose': 77,
#    'seconda_dose': 0,
#    'sesso_femminile': 39,
#    'sesso_maschile': 38},
#   {'area': 'LAZ',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 51,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI4',
#    'codice_regione_ISTAT': 12,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 39,
#    'nome_area': 'Lazio',
#    'prima_dose': 51,
#    'seconda_dose': 0,
#    'sesso_femminile': 32,
#    'sesso_maschile': 19},
#   {'area': 'LAZ',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 56,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI4',
#    'codice_regione_ISTAT': 12,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 40,
#    'nome_area': 'Lazio',
#    'prima_dose': 56,
#    'seconda_dose': 0,
#    'sesso_femminile': 30,
#    'sesso_maschile': 26},
#   {'area': 'LAZ',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 24,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI4',
#    'codice_regione_ISTAT': 12,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 41,
#    'nome_area': 'Lazio',
#    'prima_dose': 24,
#    'seconda_dose': 0,
#    'sesso_femminile': 8,
#    'sesso_maschile': 16},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 5,
#    'categoria_ospiti_rsa': 4,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 42,
#    'nome_area': 'Liguria',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 3,
#    'sesso_maschile': 6},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 20,
#    'categoria_ospiti_rsa': 4,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 43,
#    'nome_area': 'Liguria',
#    'prima_dose': 24,
#    'seconda_dose': 0,
#    'sesso_femminile': 14,
#    'sesso_maschile': 10},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 17,
#    'categoria_ospiti_rsa': 3,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 44,
#    'nome_area': 'Liguria',
#    'prima_dose': 20,
#    'seconda_dose': 0,
#    'sesso_femminile': 14,
#    'sesso_maschile': 6},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 2,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 30,
#    'categoria_ospiti_rsa': 3,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 45,
#    'nome_area': 'Liguria',
#    'prima_dose': 35,
#    'seconda_dose': 0,
#    'sesso_femminile': 19,
#    'sesso_maschile': 16},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 14,
#    'categoria_ospiti_rsa': 3,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 46,
#    'nome_area': 'Liguria',
#    'prima_dose': 17,
#    'seconda_dose': 0,
#    'sesso_femminile': 4,
#    'sesso_maschile': 13},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 2,
#    'categoria_ospiti_rsa': 3,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 47,
#    'nome_area': 'Liguria',
#    'prima_dose': 5,
#    'seconda_dose': 0,
#    'sesso_femminile': 3,
#    'sesso_maschile': 2},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 12,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 48,
#    'nome_area': 'Liguria',
#    'prima_dose': 12,
#    'seconda_dose': 0,
#    'sesso_femminile': 10,
#    'sesso_maschile': 2},
#   {'area': 'LIG',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 13,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC3',
#    'codice_regione_ISTAT': 7,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '90+',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 49,
#    'nome_area': 'Liguria',
#    'prima_dose': 13,
#    'seconda_dose': 0,
#    'sesso_femminile': 12,
#    'sesso_maschile': 1},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 1,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 35,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 6,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 50,
#    'nome_area': 'Lombardia',
#    'prima_dose': 42,
#    'seconda_dose': 0,
#    'sesso_femminile': 22,
#    'sesso_maschile': 20},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 4,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 57,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 3,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 51,
#    'nome_area': 'Lombardia',
#    'prima_dose': 64,
#    'seconda_dose': 0,
#    'sesso_femminile': 33,
#    'sesso_maschile': 31},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 8,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 119,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 14,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 1,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 52,
#    'nome_area': 'Lombardia',
#    'prima_dose': 142,
#    'seconda_dose': 0,
#    'sesso_femminile': 80,
#    'sesso_maschile': 62},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 7,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 212,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 14,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 53,
#    'nome_area': 'Lombardia',
#    'prima_dose': 233,
#    'seconda_dose': 0,
#    'sesso_femminile': 119,
#    'sesso_maschile': 114},
#   {'area': 'LOM',
#    'categoria_60_69': 13,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 180,
#    'categoria_ospiti_rsa': 2,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 6,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 54,
#    'nome_area': 'Lombardia',
#    'prima_dose': 201,
#    'seconda_dose': 0,
#    'sesso_femminile': 41,
#    'sesso_maschile': 160},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 7,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 11,
#    'categoria_ospiti_rsa': 2,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 3,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 55,
#    'nome_area': 'Lombardia',
#    'prima_dose': 23,
#    'seconda_dose': 0,
#    'sesso_femminile': 2,
#    'sesso_maschile': 21},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 1,
#    'categoria_ospiti_rsa': 8,
#    'categoria_over80': 1,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 56,
#    'nome_area': 'Lombardia',
#    'prima_dose': 10,
#    'seconda_dose': 0,
#    'sesso_femminile': 6,
#    'sesso_maschile': 4},
#   {'area': 'LOM',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 2,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITC',
#    'codice_NUTS2': 'ITC4',
#    'codice_regione_ISTAT': 3,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '90+',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 57,
#    'nome_area': 'Lombardia',
#    'prima_dose': 2,
#    'seconda_dose': 0,
#    'sesso_femminile': 1,
#    'sesso_maschile': 1},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 14,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 58,
#    'nome_area': 'Marche',
#    'prima_dose': 15,
#    'seconda_dose': 0,
#    'sesso_femminile': 9,
#    'sesso_maschile': 6},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 20,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 59,
#    'nome_area': 'Marche',
#    'prima_dose': 20,
#    'seconda_dose': 0,
#    'sesso_femminile': 15,
#    'sesso_maschile': 5},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 30,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 2,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 60,
#    'nome_area': 'Marche',
#    'prima_dose': 32,
#    'seconda_dose': 0,
#    'sesso_femminile': 22,
#    'sesso_maschile': 10},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 30,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 5,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 61,
#    'nome_area': 'Marche',
#    'prima_dose': 35,
#    'seconda_dose': 0,
#    'sesso_femminile': 22,
#    'sesso_maschile': 13},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 90,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 4,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 62,
#    'nome_area': 'Marche',
#    'prima_dose': 94,
#    'seconda_dose': 0,
#    'sesso_femminile': 31,
#    'sesso_maschile': 63},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 2,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 63,
#    'nome_area': 'Marche',
#    'prima_dose': 2,
#    'seconda_dose': 0,
#    'sesso_femminile': 2,
#    'sesso_maschile': 0},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 64,
#    'nome_area': 'Marche',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 1,
#    'sesso_maschile': 0},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '90+',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 65,
#    'nome_area': 'Marche',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 1,
#    'sesso_maschile': 0},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 3,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 66,
#    'nome_area': 'Molise',
#    'prima_dose': 4,
#    'seconda_dose': 0,
#    'sesso_femminile': 4,
#    'sesso_maschile': 0},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 8,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2020-12-27T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 67,
#    'nome_area': 'Molise',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 5,
#    'sesso_maschile': 4},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 7,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
# ...
#    'categoria_personale_non_sanitario': 9,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 979,
#    'nome_area': 'Marche',
#    'prima_dose': 358,
#    'seconda_dose': 0,
#    'sesso_femminile': 205,
#    'sesso_maschile': 153},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 2,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 374,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 27,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 980,
#    'nome_area': 'Marche',
#    'prima_dose': 403,
#    'seconda_dose': 0,
#    'sesso_femminile': 269,
#    'sesso_maschile': 134},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 5,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 403,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 49,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 981,
#    'nome_area': 'Marche',
#    'prima_dose': 457,
#    'seconda_dose': 0,
#    'sesso_femminile': 311,
#    'sesso_maschile': 146},
#   {'area': 'MAR',
#    'categoria_60_69': 3,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 198,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 22,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 982,
#    'nome_area': 'Marche',
#    'prima_dose': 223,
#    'seconda_dose': 0,
#    'sesso_femminile': 113,
#    'sesso_maschile': 110},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 2,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 7,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 983,
#    'nome_area': 'Marche',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 2,
#    'sesso_maschile': 7},
#   {'area': 'MAR',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 0,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 1,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITI',
#    'codice_NUTS2': 'ITI3',
#    'codice_regione_ISTAT': 11,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '80-89',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 984,
#    'nome_area': 'Marche',
#    'prima_dose': 1,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 1},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 15,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 985,
#    'nome_area': 'Molise',
#    'prima_dose': 15,
#    'seconda_dose': 0,
#    'sesso_femminile': 9,
#    'sesso_maschile': 6},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 60,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 986,
#    'nome_area': 'Molise',
#    'prima_dose': 60,
#    'seconda_dose': 0,
#    'sesso_femminile': 39,
#    'sesso_maschile': 21},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 2,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 99,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 987,
#    'nome_area': 'Molise',
#    'prima_dose': 101,
#    'seconda_dose': 0,
#    'sesso_femminile': 67,
#    'sesso_maschile': 34},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 5,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 158,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 988,
#    'nome_area': 'Molise',
#    'prima_dose': 163,
#    'seconda_dose': 0,
#    'sesso_femminile': 104,
#    'sesso_maschile': 59},
#   {'area': 'MOL',
#    'categoria_60_69': 1,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 107,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 989,
#    'nome_area': 'Molise',
#    'prima_dose': 108,
#    'seconda_dose': 0,
#    'sesso_femminile': 50,
#    'sesso_maschile': 58},
#   {'area': 'MOL',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 2,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITF',
#    'codice_NUTS2': 'ITF2',
#    'codice_regione_ISTAT': 14,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 990,
#    'nome_area': 'Molise',
#    'prima_dose': 2,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 2},
#   {'area': 'PAB',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 2,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 56,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 2,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 991,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 60,
#    'seconda_dose': 0,
#    'sesso_femminile': 46,
#    'sesso_maschile': 14},
#   {'area': 'PAB',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 5,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 116,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 5,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 992,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 126,
#    'seconda_dose': 0,
#    'sesso_femminile': 77,
#    'sesso_maschile': 49},
#   {'area': 'PAB',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 10,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 228,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 17,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 993,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 255,
#    'seconda_dose': 0,
#    'sesso_femminile': 184,
#    'sesso_maschile': 71},
#   {'area': 'PAB',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 7,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 238,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 33,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '50-59',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 994,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 278,
#    'seconda_dose': 0,
#    'sesso_femminile': 193,
#    'sesso_maschile': 85},
#   {'area': 'PAB',
#    'categoria_60_69': 8,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 89,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 5,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '60-69',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 995,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 102,
#    'seconda_dose': 0,
#    'sesso_femminile': 44,
#    'sesso_maschile': 58},
#   {'area': 'PAB',
#    'categoria_60_69': 0,
#    'categoria_70_79': 2,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 7,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 0,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH1',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '70-79',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 996,
#    'nome_area': 'Provincia Autonoma Bolzano / Bozen',
#    'prima_dose': 9,
#    'seconda_dose': 0,
#    'sesso_femminile': 0,
#    'sesso_maschile': 9},
#   {'area': 'PAT',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 54,
#    'categoria_ospiti_rsa': 1,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 3,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH2',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '20-29',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 997,
#    'nome_area': 'Provincia Autonoma Trento',
#    'prima_dose': 58,
#    'seconda_dose': 0,
#    'sesso_femminile': 45,
#    'sesso_maschile': 13},
#   {'area': 'PAT',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 2,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 93,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 11,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH2',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '30-39',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 998,
#    'nome_area': 'Provincia Autonoma Trento',
#    'prima_dose': 106,
#    'seconda_dose': 0,
#    'sesso_femminile': 69,
#    'sesso_maschile': 37},
#   {'area': 'PAT',
#    'categoria_60_69': 0,
#    'categoria_70_79': 0,
#    'categoria_altro': 0,
#    'categoria_forze_armate': 0,
#    'categoria_operatori_sanitari_sociosanitari': 142,
#    'categoria_ospiti_rsa': 0,
#    'categoria_over80': 0,
#    'categoria_personale_non_sanitario': 8,
#    'categoria_personale_scolastico': 0,
#    'categoria_soggetti_fragili': 0,
#    'codice_NUTS1': 'ITH',
#    'codice_NUTS2': 'ITH2',
#    'codice_regione_ISTAT': 4,
#    'data_somministrazione': '2021-01-05T00:00:00.000Z',
#    'fascia_anagrafica': '40-49',
#    'fornitore': 'Pfizer/BioNTech',
#    'index': 999,
#    'nome_area': 'Provincia Autonoma Trento',
#    'prima_dose': 150,
#    'seconda_dose': 0,
#    'sesso_femminile': 95,
#    'sesso_maschile': 55},
#   ...],
#  'schema': {'fields': [{'name': 'index', 'type': 'integer'},
#    {'name': 'data_somministrazione', 'type': 'datetime'},
#    {'name': 'fornitore', 'type': 'string'},
#    {'name': 'area', 'type': 'string'},
#    {'name': 'fascia_anagrafica', 'type': 'string'},
#    {'name': 'sesso_maschile', 'type': 'integer'},
#    {'name': 'sesso_femminile', 'type': 'integer'},
#    {'name': 'categoria_operatori_sanitari_sociosanitari', 'type': 'integer'},
#    {'name': 'categoria_personale_non_sanitario', 'type': 'integer'},
#    {'name': 'categoria_ospiti_rsa', 'type': 'integer'},
#    {'name': 'categoria_60_69', 'type': 'integer'},
#    {'name': 'categoria_70_79', 'type': 'integer'},
#    {'name': 'categoria_over80', 'type': 'integer'},
#    {'name': 'categoria_forze_armate', 'type': 'integer'},
#    {'name': 'categoria_personale_scolastico', 'type': 'integer'},
#    {'name': 'categoria_soggetti_fragili', 'type': 'integer'},
#    {'name': 'categoria_altro', 'type': 'integer'},
#    {'name': 'prima_dose', 'type': 'integer'},
#    {'name': 'seconda_dose', 'type': 'integer'},
#    {'name': 'codice_NUTS1', 'type': 'string'},
#    {'name': 'codice_NUTS2', 'type': 'string'},
#    {'name': 'codice_regione_ISTAT', 'type': 'integer'},
#    {'name': 'nome_area', 'type': 'string'}],
#   'pandas_version': '0.20.0',
#   'primaryKey': ['index']}}
