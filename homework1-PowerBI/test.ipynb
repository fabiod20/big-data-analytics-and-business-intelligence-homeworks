# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("dataset/vaccine/somministrazioni-vaccini-latest.csv")
dataset.drop(columns=["categoria_operatori_sanitari_sociosanitari", "categoria_personale_non_sanitario", "categoria_operatori_sanitari_sociosanitari", "categoria_personale_non_sanitario", "categoria_ospiti_rsa", "categoria_over80", "categoria_forze_armate","categoria_personale_scolastico", "categoria_altro", "prima_dose", "seconda_dose"], inplace=True)
dataset["id"] = dataset.index
dataset.head()
# Out:
#   data_somministrazione        fornitore area fascia_anagrafica  \
# 0            2020-12-27  Pfizer/BioNTech  ABR             20-29
# 1            2020-12-27  Pfizer/BioNTech  ABR             30-39
# 2            2020-12-27  Pfizer/BioNTech  ABR             40-49
# 3            2020-12-27  Pfizer/BioNTech  ABR             50-59
# 4            2020-12-27  Pfizer/BioNTech  ABR             60-69
#
#    sesso_maschile  sesso_femminile codice_NUTS1 codice_NUTS2  \
# 0               1                0          ITF         ITF1
# 1               1                3          ITF         ITF1
# 2               1                6          ITF         ITF1
# 3               4                5          ITF         ITF1
# 4              10                4          ITF         ITF1
#
#    codice_regione_ISTAT nome_area  id
# 0                    13   Abruzzo   0
# 1                    13   Abruzzo   1
# 2                    13   Abruzzo   2
# 3                    13   Abruzzo   3
# ...

# %%
dataset = pd.wide_to_long(dataset, "sesso", i="id", j="gender", sep="_", suffix='\D+')
dataset.head()
# Out:
#             data_somministrazione codice_NUTS2 area  codice_regione_ISTAT  \
# id gender
# 0  maschile            2020-12-27         ITF1  ABR                    13
# 1  maschile            2020-12-27         ITF1  ABR                    13
# 2  maschile            2020-12-27         ITF1  ABR                    13
# 3  maschile            2020-12-27         ITF1  ABR                    13
# 4  maschile            2020-12-27         ITF1  ABR                    13
#
#             codice_NUTS1 nome_area        fornitore fascia_anagrafica  sesso
# id gender
# 0  maschile          ITF   Abruzzo  Pfizer/BioNTech             20-29      1
# 1  maschile          ITF   Abruzzo  Pfizer/BioNTech             30-39      1
# 2  maschile          ITF   Abruzzo  Pfizer/BioNTech             40-49      1
# 3  maschile          ITF   Abruzzo  Pfizer/BioNTech             50-59      4
# 4  maschile          ITF   Abruzzo  Pfizer/BioNTech             60-69     10

# %%
dataset.reset_index()
# Out:
#           id     gender data_somministrazione codice_NUTS2 area  \
# 0          0   maschile            2020-12-27         ITF1  ABR
# 1          1   maschile            2020-12-27         ITF1  ABR
# 2          2   maschile            2020-12-27         ITF1  ABR
# 3          3   maschile            2020-12-27         ITF1  ABR
# 4          4   maschile            2020-12-27         ITF1  ABR
# 5          5   maschile            2020-12-27         ITF1  ABR
# 6          6   maschile            2020-12-27         ITF1  ABR
# 7          7   maschile            2020-12-27         ITF5  BAS
# 8          8   maschile            2020-12-27         ITF5  BAS
# 9          9   maschile            2020-12-27         ITF5  BAS
# 10        10   maschile            2020-12-27         ITF5  BAS
# 11        11   maschile            2020-12-27         ITF5  BAS
# 12        12   maschile            2020-12-27         ITF6  CAL
# 13        13   maschile            2020-12-27         ITF6  CAL
# ...

# %%
np.random.seed(123)
df = pd.DataFrame({"A1970" : {0 : "a", 1 : "b", 2 : "c"},
                   "A1980" : {0 : "d", 1 : "e", 2 : "f"},
                   "B1970" : {0 : 2.5, 1 : 1.2, 2 : .7},
                   "B1980" : {0 : 3.2, 1 : 1.3, 2 : .1},
                   "X"     : dict(zip(range(3), np.random.randn(3)))
                  })
df["id"] = df.index
df
# Out:
#   A1970 A1980  B1970  B1980         X  id
# 0     a     d    2.5    3.2 -1.085631   0
# 1     b     e    1.2    1.3  0.997345   1
# 2     c     f    0.7    0.1  0.282978   2

# %%
pd.wide_to_long(df, ["A", "B"], i="id", j="year")
# Out:
#                 X  A    B
# id year
# 0  1970 -1.085631  a  2.5
# 1  1970  0.997345  b  1.2
# 2  1970  0.282978  c  0.7
# 0  1980 -1.085631  d  3.2
# 1  1980  0.997345  e  1.3
# 2  1980  0.282978  f  0.1
