# %%
import pandas as pd

dataset = pd.read_csv("dataset/vaccine/somministrazioni-vaccini-latest.csv')
dataset.head()
# Out:
#   data_somministrazione        fornitore area fascia_anagrafica  \
# 0            2020-12-27  Pfizer/BioNTech  ABR             20-29
# 1            2020-12-27  Pfizer/BioNTech  ABR             30-39
# 2            2020-12-27  Pfizer/BioNTech  ABR             40-49
# 3            2020-12-27  Pfizer/BioNTech  ABR             50-59
# 4            2020-12-27  Pfizer/BioNTech  ABR             60-69
#
#    sesso_maschile  sesso_femminile  \
# 0               1                0
# 1               1                3
# 2               1                6
# 3               4                5
# 4              10                4
#
#    categoria_operatori_sanitari_sociosanitari  \
# 0                                           1
# 1                                           4
# 2                                           7
# 3                                           9
# 4                                          13
#
#    categoria_personale_non_sanitario  categoria_ospiti_rsa  categoria_over80  \
# 0                                  0                     0                 0
# 1                                  0                     0                 0
# 2                                  0                     0                 0
# 3                                  0                     0                 0
# 4                                  0                     0                 0
#
#    categoria_forze_armate  categoria_personale_scolastico  categoria_altro  \
# 0                       0                               0                0
# 1                       0                               0                0
# 2                       0                               0                0
# 3                       0                               0                0
# 4                       0                               0                1
#
#    prima_dose  seconda_dose codice_NUTS1 codice_NUTS2  codice_regione_ISTAT  \
# 0           1             0          ITF         ITF1                    13
# 1           4             0          ITF         ITF1                    13
# 2           7             0          ITF         ITF1                    13
# 3           9             0          ITF         ITF1                    13
# 4          14             0          ITF         ITF1                    13
#
#   nome_area
# 0   Abruzzo
# 1   Abruzzo
# 2   Abruzzo
# 3   Abruzzo
# 4   Abruzzo

# %%
dataset = pd.wide_to_long(dataset, ["sesso"], , j="gender", sep='_')
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5f8a17dc785e> in <module>()
# ----> 1 dataset = pd.wide_to_long(dataset, ["sesso"], i="area", j="gender", sep='_')
#       2 dataset.head()
#
# C:\Users\fabio\Anaconda3\envs\BDBI\lib\site-packages\pandas\core\reshape\melt.py in wide_to_long(df, stubnames, i, j, sep, suffix)
#     426
#     427     if df[i].duplicated().any():
# --> 428         raise ValueError("the id variables need to uniquely identify each row")
#     429
#     430     value_vars = [get_var_names(df, stub, sep, suffix) for stub in stubnames]
#
# ValueError: the id variables need to uniquely identify each row
